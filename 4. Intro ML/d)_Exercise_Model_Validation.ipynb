# %% [markdown]
# <a href="https://colab.research.google.com/github/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/blob/main/d)_Exercise_Model_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Recapitulando**
#
# Has creado un modelo. En este ejercicio, pondrás a prueba qué tan bueno es tu modelo.
#
# Ejecuta laa celdas de abajo para configurar tu entorno de programación donde se dejó el ejercicio anterior.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nickptaylor/iowa-house-prices")

print("Path to dataset files:", path)

# %%
import pandas as pd
import os

# Load the data into a pandas DataFrame
home_data_path = path + '/train.csv'
home_data = pd.read_csv(home_data_path)

# Print the first 5 rows of the DataFrame
display(home_data.head())

# %%
# Code you have previously used to load data
from sklearn.tree import DecisionTreeRegressor

y = home_data.SalePrice
feature_columns = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[feature_columns]

# Specify Model
iowa_model = DecisionTreeRegressor()
# Fit Model
iowa_model.fit(X, y)

print("First in-sample predictions:", iowa_model.predict(X.head()))
print("Actual target values for those homes:", y.head().tolist())

# %% [markdown]
# ## **Ejercicios**
#
# ### **Paso 1: Divide tus datos**
#
# Usa la función train_test_split para dividir tus datos.
#
# Dale el argumento random_state=1 para que las funciones de verificación sepan qué esperar al verificar tu código.
#
# Recuerda, tus características están cargadas en el DataFrame **X** y tu objetivo está cargado en **y**.

# %%
# Tu código acá:

# %% [markdown]
# ### **Paso 2: Especificar y Ajustar el Modelo**
#
# Crea un modelo DecisionTreeRegressor y ajústalo a los datos relevantes. Vuelve a establecer random_state en 1 al crear el modelo.

# %%
# Tu código acá:

# %% [markdown]
# ### **Paso 3: Haz Predicciones con Datos de Validación**

# %%
# Tu código acá:

# %% [markdown]
# Inspecciona tus predicciones y los valores reales de los datos de validación.

# %%
# Tu código acá:
# imprime las primeras predicciones de la validación
print()

# imprime los primeros precios reales de los datos de validación
print()

# %% [markdown]
# ¿Qué notas que es diferente de lo que viste con las predicciones dentro de la muestra (que se imprimen después de la celda de código superior en esta página)?
#
# ¿Recuerdas por qué las predicciones de validación difieren de las predicciones dentro de la muestra (o de entrenamiento)? Esta es una idea importante de la lección anterior.
#
# ### **Paso 4: Calcular el Error Absoluto Medio en los Datos de Validación**

# %%
# Tu código acá:
from sklearn.metrics import mean_absolute_error


# imprime el error absoluto medio
print()

# %% [markdown]
# ¿Ese `MAE` es bueno? No existe una regla general que aplique a todas las aplicaciones para determinar qué valores son buenos. Pero verás cómo usar (y mejorar) este número en el siguiente paso.
