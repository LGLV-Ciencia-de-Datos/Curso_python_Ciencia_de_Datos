# %% [markdown]
# <a href="https://colab.research.google.com/github/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/blob/main/c)_Exercise_Your_First_ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Recapitulación**
#
# Hemos cargado y revisado tus datos usando el código que se muestra. Ejecuta estas celdas para retomar tu entorno de programación justo donde lo dejamos.

# %%
import pandas as pd
import os

import kagglehub

# Download latest version
path = kagglehub.dataset_download("nickptaylor/iowa-house-prices")

print("Path to dataset files:", path)

# %%
# Load the data into a pandas DataFrame
home_data_path = path + '/train.csv'
home_data = pd.read_csv(home_data_path)

# Print the first 5 rows of the DataFrame
display(home_data.head())

# %% [markdown]
# ## **Ejercicios**
#
# ### **Paso 1: Especificar la variable objetivo de la predicción**
#
# Selecciona la variable objetivo, que corresponde al precio de venta. Guárdala en una nueva variable llamada `y`. Tendrás que imprimir una lista de las columnas para encontrar el nombre de la columna que necesitas.

# %%
home_data.columns

# %%
# Tu código aca:

# %% [markdown]
# ## **Paso 2: Crear X**
#
# Ahora crearás un DataFrame llamado X que contendrá las características predictivas.
#
# Dado que solo quieres algunas columnas de los datos originales, primero crearás una lista con los nombres de las columnas que deseas en X.
#
# Usarás solo las siguientes columnas en la lista (puedes copiar y pegar la lista completa para ahorrarte algo de escritura, aunque aún necesitarás añadir comillas):
#
#     LotArea
#
#     YearBuilt
#
#     1stFlrSF
#
#     2ndFlrSF
#
#     FullBath
#
#     BedroomAbvGr
#
#     TotRmsAbvGrd
#
# Una vez que hayas creado esa lista de características, úsala para crear el DataFrame que utilizarás para ajustar el modelo.

# %%
# Tu código aca:

# %% [markdown]
# ## **Revisar los Datos**
#
# Antes de construir un modelo, echa un vistazo rápido a X para verificar que se vea sensato.

# %%
# Tu código aca:

# %%
# Tu código aca:

# %% [markdown]
# ## **Paso 3: Especificar y Entrenar el Modelo**
#
# Crea un `DecisionTreeRegressor` y guárdalo como `iowa_model`. Asegúrate de haber realizado la importación relevante de `sklearn` para ejecutar este comando.
#
# Luego, entrena el modelo que acabas de crear usando los datos de `X` e `y` que guardaste anteriormente.

# %%
# Tu código aca:

# %% [markdown]
# ## **Paso 4: Realizar predicciones**
#
# Realiza predicciones con el comando `predict` del modelo usando `X` como los datos. Guarda los resultados en una variable llamada `predictions`.

# %%
# Tu código aca:

# %% [markdown]
# ## **Piensa en tus resultados.**
#
# Utiliza el método head para comparar las primeras predicciones con los valores de casas reales `y`para esas mismas viviendas. ¿Hay algo sorprendente?

# %%
# Tu código aca:

# %%
# Tu código aca:

# %% [markdown]
# Es natural preguntarse qué tan precisas serán las predicciones del modelo y cómo puedes mejorarlas. Ese será tu siguiente paso.
