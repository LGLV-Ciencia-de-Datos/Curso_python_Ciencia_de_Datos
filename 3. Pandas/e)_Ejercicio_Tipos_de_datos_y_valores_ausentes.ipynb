# %% [markdown]
# <a href="https://colab.research.google.com/github/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/blob/main/e)_Ejercicio_Tipos_de_datos_y_valores_ausentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introducción**
#
# Ejecuta la siguiente celda para cargar tus datos

# %%
reviews = pd.read_csv('https://raw.githubusercontent.com/davestroud/Wine/refs/heads/master/winemag-data-130k-v2.csv', index_col = 0)
reviews.head()

# %% [markdown]
# ## 1.
#
# ¿Cuál es el tipo de dato de la columna "points" en el conjunto de datos?

# %%
# Tu código aca:

# %% [markdown]
# ## 2.
#
# Crea una Serie a partir de las entradas en la columna de puntos, pero convierte las entradas a cadenas de caracteres. Pista: las cadenas son str en Python nativo.

# %%
# Tu código aca:

# %% [markdown]
# ## 3.
# A veces la columna de precio es nula. ¿Cuántas reseñas en el conjunto de datos no tienen precio?

# %%
# Tu código aca:

# %% [markdown]
# ## 4.
# ¿Cuáles son las regiones vinícolas más comunes? Crea una Serie que cuente el número de veces que cada valor aparece en el campo region_1. Este campo a menudo carece de datos, por lo que debes reemplazar los valores faltantes con Unknown. Ordena de forma descendente. Tu resultado debe verse de la siguiente manera:
#
# ```
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
# Tu código aca:
