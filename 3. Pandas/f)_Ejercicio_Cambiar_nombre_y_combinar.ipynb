# %% [markdown]
# <a href="https://colab.research.google.com/github/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/blob/main/f)_Ejercicio_Cambiar_nombre_y_combinar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introducción**
#
# Ejecuta la siguiente celda para cargar tus datos

# %%
import pandas as pd

# %%
reviews = pd.read_csv('https://raw.githubusercontent.com/davestroud/Wine/refs/heads/master/winemag-data-130k-v2.csv', index_col = 0)
reviews.head()

# %% [markdown]
# ## 1.
# region_1 y region_2 son nombres poco informativos para las columnas de ubicación en el conjunto de datos. Crea una copia de las reseñas con estas columnas renombradas a region y locale, respectivamente.

# %%
# Tu código aca:

# %% [markdown]
# ## 2.
#
# Establece el nombre del índice en el conjunto de datos como "wines".

# %%
# Tu código aca:

# %% [markdown]
# ## 3.
#
# El conjunto de datos [Things on Reddit](https://www.kaggle.com/datasets/residentmario/things-on-reddit/data) incluye enlaces de productos de una selección de los foros mejor clasificados ("subreddits") en reddit.com. Ejecute la siguiente celda para cargar un dataframe de los productos mencionados en el `subreddit /r/gaming` y otro dataframe para los productos mencionados en el `subreddit /r/movies`.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("residentmario/things-on-reddit")

print("Path to dataset files:", path)

# %%
import os

gaming_products = pd.read_csv(os.path.join(path, 'top-things', 'top-things', 'reddits', 'g', 'gaming.csv'))
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv(os.path.join(path, 'top-things', 'top-things', 'reddits', 'm', 'movies.csv'))
movie_products['subreddit'] = "r/movies"

# %% [markdown]
# Crea un DataFrame de los productos mencionados en cualquiera de los dos subreddits.

# %%
# Tu código aca:

# %% [markdown]
# ## 4.
#
# El conjunto de datos de la Base de Datos de [Powerlifting](https://www.kaggle.com/datasets/open-powerlifting/powerlifting-database) en Kaggle incluye una tabla CSV para encuentros de levantamiento de pesas y otra separada para los competidores. Ejecuta la celda de abajo para cargar estos conjuntos de datos en dataframes:

# %%
# ejecuta esta celda de codigo
url = 'https://raw.githubusercontent.com/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/refs/heads/main/meets_reduced.csv'
powerlifting_meets = pd.read_csv(url)
powerlifting_meets.shape

# %%
# ejecuta esta celda de codigo
url_2 = 'https://raw.githubusercontent.com/LGLV-Ciencia-de-Datos/Curso_python_Ciencia_de_Datos/refs/heads/main/powerlifting_competitors_reduced.csv'
powerlifting_competitors = pd.read_csv(url_2)
powerlifting_competitors.shape

# %% [markdown]
# Ambas tablas incluyen referencias a un `MeetID`, una clave única para cada encuentro (competición) incluida en la base de datos. Usando esto, genera un conjunto de datos que combine las dos tablas en una sola.

# %%
# Tu código aca:
